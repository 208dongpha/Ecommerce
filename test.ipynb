# %%
# # Install dependencies as needed:
# # pip install kagglehub[pandas-datasets]
# import os
# import pandas as pd
# import kagglehub

# DATASET_HANDLE = "zusmani/pakistans-largest-ecommerce-dataset"

# # If you know the exact file inside the dataset, set it here (relative or absolute)
# # Example: file_path = "Pakistan Largest Ecommerce Dataset.csv"
# file_path = ""

# # Download the dataset locally
# download_dir = kagglehub.dataset_download(DATASET_HANDLE)
# print("Dataset downloaded to:", download_dir)

# # Map supported extensions to the appropriate pandas reader
# supported_exts = {
#     ".csv": pd.read_csv,
#     ".tsv": lambda p: pd.read_csv(p, sep="\t"),
#     ".json": pd.read_json,
#     ".jsonl": lambda p: pd.read_json(p, lines=True),
#     ".parquet": pd.read_parquet,
#     ".feather": pd.read_feather,
#     ".xlsx": pd.read_excel,
#     ".xls": pd.read_excel,
#     ".xlsm": pd.read_excel,
#     ".xlsb": pd.read_excel,
#     ".xml": pd.read_xml,
# }

# # Auto-select the first supported file if none is provided
# if not file_path:
#     candidates = []
#     for root, _, files in os.walk(download_dir):
#         for name in files:
#             ext = os.path.splitext(name)[1].lower()
#             if ext in supported_exts:
#                 candidates.append(os.path.join(root, name))
#     if not candidates:
#         raise ValueError(f"No supported files found in {download_dir}")
#     file_path = candidates[0]
#     print("Auto-selected file:", file_path)

# ext = os.path.splitext(file_path)[1].lower()
# if ext not in supported_exts:
#     raise ValueError(f"Unsupported file extension: {ext}")

# read_fn = supported_exts[ext]
# df = read_fn(file_path)

# print("First 5 records:")
# print(df.head())
# Out:
# ...
# 100%|██████████| 13.8M/13.8M [00:02<00:00, 7.13MB/s]
# Extracting files...
# Dataset downloaded to: C:\Users\Admin\.cache\kagglehub\datasets\zusmani\pakistans-largest-ecommerce-dataset\versions\2
# Auto-selected file: C:\Users\Admin\.cache\kagglehub\datasets\zusmani\pakistans-largest-ecommerce-dataset\versions\2\Pakistan Largest Ecommerce Dataset.csv
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15268\1028421747.py:50: DtypeWarning: Columns (1,2,3,7,8,9,11,12,13,14,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = read_fn(file_path)
# First 5 records:
#     item_id          status created_at  \
# 0  211131.0        complete   7/1/2016
# 1  211133.0        canceled   7/1/2016
# 2  211134.0        canceled   7/1/2016
# 3  211135.0        complete   7/1/2016
# 4  211136.0  order_refunded   7/1/2016
#
#                                                  sku   price  qty_ordered  \
# ...

# %%
import pandas as pd
import pyspark as py
import numpy as np

# %%
df = pd.read_csv('Pakistan Largest Ecommerce Dataset.csv')
print(df.info())
print(df.describe())
print(df.head(10).to_markdown())
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15268\4221853467.py:1: DtypeWarning: Columns (1,2,3,7,8,9,11,12,13,14,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Pakistan Largest Ecommerce Dataset.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                584524 non-null  float64
#  1   status                 584509 non-null  object
#  2   created_at             584524 non-null  object
#  3   sku                    584504 non-null  object
#  4   price                  584524 non-null  float64
#  5   qty_ordered            584524 non-null  float64
#  6   grand_total            584524 non-null  float64
#  7   increment_id           584524 non-null  object
#  8   category_name_1        584360 non-null  object
# ...
